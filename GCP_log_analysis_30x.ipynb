# %%
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# %%
filenames = [f for f in os.listdir('./run_2_logs') if f[-3:] == 'csv']

# %%
os.getcwd()
# Out:
# '/Users/everyday/UNM/CS_Moses/gcp_data_analysis'

# %%
# df = pd.DataFrame(columns=['trialId', 
#                            'rateOfLayingPheromone', 
#                            'probabilityOfSwitchingToSearching',
#                            'probabilityOfReturningToNest',
#                            'rateOfInformedSearchDecay',
#                            'rateOfSiteFidelity',
#                            'rateOfPheromoneDecay',
#                            'uninformedSearchVariation',
#                            'foodDistribution',
#                            'fitnessScore'
#                           ])
df = pd.DataFrame()

# %%
trialcount = 0;
rowsList = []
for file in filenames:
    with open(os.path.join('./run_2_logs', file)) as csv_file:
        csvreader = csv.DictReader(csv_file)        
        trialcount += 1
        currentTrial = None
        rateOfLayingPheromone = None
        probabilityOfSwitchingToSearching = None
        probabilityOfReturningToNest = None
        rateOfInformedSearchDecay = None
        rateOfSiteFidelity = None
        rateOfPheromoneDecay = None
        uninformedSearchVariation = None
        foodDistribution = []
        fitnessScore = None
        
        for row in csvreader:
#             print(row)
            current_trial = row['labels."ml.googleapis.com/trial_id"']
            message = row['jsonPayload.message'].strip()
            if (currentTrial is None):
                currentTrial = row['labels."ml.googleapis.com/trial_id"']
#                 print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL {} - {}".format(trialcount, current_trial))
            if ('RateOfLayingPheromone' in message):
                rateOfLayingPheromone = message.split()[1]
#                 print('RateOfLayingPheromone ->', rateOfLayingPheromone)
            if ('ProbabilityOfSwitchingToSearching' in message):
                probabilityOfSwitchingToSearching = message.split()[1]
#                 print('ProbabilityOfSwitchingToSearching ->', probabilityOfSwitchingToSearching)
            if ('ProbabilityOfReturningToNest' in message):
                probabilityOfReturningToNest = message.split()[1]
#                 print('ProbabilityOfReturningToNest ->', probabilityOfReturningToNest)
            if ('RateOfInformedSearchDecay' in message):
                rateOfInformedSearchDecay = message.split()[1]
#                 print('RateOfInformedSearchDecay ->', rateOfInformedSearchDecay)
            if ('RateOfSiteFidelity' in message):
                rateOfSiteFidelity = message.split()[1]
#                 print('RateOfSiteFidelity ->', rateOfSiteFidelity)
            if ('RateOfPheromoneDecay' in message):
                rateOfPheromoneDecay = message.split()[1]
#                 print('RateOfPheromoneDecay ->', rateOfPheromoneDecay)
            if ('UninformedSearchVariation' in message):
                uninformedSearchVariation = message.split()[1]
#                 print('UninformedSearchVariation ->', uninformedSearchVariation)
            if ('food distribution' in message and 'randomizing' not in message):
                pass
#                 print('food distribution ->', message.split()[2])
            if ('food distribution' in message and 'randomizing' not in message):
                foodDistribution.append(message.split()[2])
#                 print('foodDistribution ->', message.split()[2])
            if ('Fitness Score' in message):
                fitnessScore = message.split()[3]
#                 print('Fitness Score ---->', fitnessScore)
#             if (len(foodDistribution) == 30):
# #                 print('FOODS', foodDistribution)
#                 break
        rowsList.append({'currentTrial': int(currentTrial),
                  'rateOfLayingPheromone': float(rateOfLayingPheromone),
                  'probabilityOfSwitchingToSearching': float(probabilityOfSwitchingToSearching),
                  'probabilityOfReturningToNest': float(probabilityOfReturningToNest),
                  'rateOfInformedSearchDecay': float(rateOfInformedSearchDecay),
                  'rateOfSiteFidelity': float(rateOfSiteFidelity),
#                   'rateOfPheromoneDecay': float(rateOfPheromoneDecay),
                  'uninformedSearchVariation': float(uninformedSearchVariation),
#                   'foodDistribution': foodDistribution,
                  'fitnessScore': float(fitnessScore)})
            
#         print(rowsList)

# %%
df = pd.DataFrame(rowsList)
df
# Out:
#     currentTrial  fitnessScore  probabilityOfReturningToNest  \
# 0             57      0.739062                      0.000368
# 1            923      0.740885                      0.000027
# 2            909      0.733203                      0.000048
# 3             83      0.731380                      0.000285
# 4             50      0.737240                      0.000413
# 5             79      0.742969                      0.000384
# 6            886      0.733203                      0.000531
# 7            104      0.741146                      0.000427
# 8            851      0.759635                      0.000339
# 9            462      0.729297                      0.000248
# 10           476      0.734115                      0.000342
# 11           311      0.732943                      0.000188
# 12           148      0.757682                      0.000282
# 13           558      0.732292                      0.000118
# 14           175      0.738802                      0.000286
# 15           161      0.739323                      0.000257
# 16           411      0.744010                      0.000409
# 17           163      0.735026                      0.000337
# 18           201      0.738151                      0.000265
# 19           215      0.733594                      0.000329
# 20           572      0.728516                      0.000143
# 21           615      0.728646                      0.000370
# 22           814      0.732812                      0.000324
# 23           236      0.730599                      0.000111
# 24           626      0.735677                      0.000493
# 25           168      0.729948                      0.000395
# 26           381      0.732161                      0.000142
# 27           624      0.730990                      0.001019
# 28           750      0.734896                      0.000191
# 29           341      0.772396                      0.000209
# 30           351      0.742188                      0.000401
# 31           225      0.731641                      0.000367
# 32           352      0.744922                      0.000295
# 33           569      0.732422                      0.000040
# 34           964      0.728255                      0.000152
# 35           145      0.737240                      0.000091
# 36           804      0.732812                      0.000163
# 37           421      0.733464                      0.000215
# 38           718      0.740234                      0.000175
# 39           255      0.732031                      0.000025
# 40           530      0.738802                      0.000048
# 41           440      0.731901                      0.000397
# 42            65      0.732943                      0.000273
# 43           722      0.739844                      0.000577
# 44           680      0.775911                      0.000064
# 45           441      0.729036                      0.000017
# 46           333      0.736068                      0.000325
# 47           696      0.740885                      0.000158
# 48           127      0.741276                      0.000041
# 49           523      0.744922                      0.000016
#
#     probabilityOfSwitchingToSearching  rateOfInformedSearchDecay  \
# 0                            0.575400                 115.999659
# 1                            0.786281                   1.280534
# 2                            0.784683                   8.235364
# 3                            0.558484                  87.618961
# 4                            0.543378                 101.758465
# 5                            0.564561                 134.163755
# 6                            0.300654                   8.913571
# 7                            0.539895                 144.483967
# 8                            0.450839                 128.547649
# 9                            0.357151                 114.764416
# 10                           0.561767                 101.082655
# 11                           0.414198                  31.584774
# 12                           0.559105                  45.115321
# 13                           0.365769                  26.302698
# 14                           0.761342                  84.908671
# 15                           0.554373                  15.430934
# 16                           0.462281                 138.236727
# 17                           0.435779                   0.211933
# 18                           0.321163                   0.515256
# 19                           0.454639                 130.559112
# 20                           0.719818                  90.089951
# 21                           0.540512                 140.967719
# 22                           0.510283                 147.258363
# 23                           0.789840                   2.437364
# 24                           0.508028                  93.065257
# 25                           0.753169                  64.642482
# 26                           0.722672                  14.135857
# 27                           0.389220                   2.735747
# 28                           0.374009                  12.906699
# 29                           0.442561                 117.065655
# 30                           0.469438                 119.965551
# 31                           0.319697                  45.984988
# 32                           0.471494                 130.379508
# 33                           0.794663                 126.133041
# 34                           0.424620                  30.435890
# 35                           0.759937                 134.702759
# 36                           0.396366                  35.685991
# 37                           0.378133                   1.205339
# 38                           0.405248                   7.917391
# 39                           0.776770                   3.023918
# 40                           0.741877                  72.062060
# 41                           0.484288                  28.261637
# 42                           0.563297                 125.921705
# 43                           0.305343                  89.551576
# 44                           0.774708                   0.917383
# 45                           0.575908                  40.814504
# 46                           0.597508                 129.761782
# 47                           0.786496                 145.964818
# 48                           0.764206                   0.740577
# 49                           0.580068                 137.334987
#
#     rateOfLayingPheromone  rateOfSiteFidelity  uninformedSearchVariation
# 0                2.610707            3.052581                   4.058874
# 1                2.115808            8.518442                   1.896209
# 2                3.757197            1.664933                   3.785895
# 3                2.397754            4.147468                   3.114857
# 4                2.910179            3.397469                   3.168691
# 5                2.378224            8.381731                   4.032645
# 6                2.501850            9.462469                   5.756630
# 7                4.930410            3.831122                   2.567733
# 8                5.469251            1.580790                   4.524871
# 9                4.270191            0.310286                   4.259732
# 10               3.996388            7.598072                   3.877404
# 11               5.221859            3.091224                   4.403281
# 12               3.632227            9.545652                   3.557932
# 13               7.542136            2.700060                   0.277554
# 14               1.943273            6.215428                   3.823076
# 15               3.136237            9.393208                   3.552611
# 16               4.487030            3.767829                   4.769360
# 17               4.780435            3.818971                   3.182430
# 18               2.000959            3.979085                   4.819623
# 19               4.298871            3.298073                   4.220935
# 20               1.378910            3.869037                   3.892418
# 21               1.925932            4.214499                   2.795011
# 22               0.840770            4.550686                   6.554153
# 23               2.285080            8.744993                   5.740117
# 24               2.633257            3.978130                   3.642160
# 25               0.819968            4.605619                   6.142793
# 26               3.951295            1.521387                   5.279894
# 27               3.178618            2.491204                   5.272880
# 28               4.703247            2.906127                   0.868311
# 29               4.324844            3.292195                   3.103513
# 30               5.098221            2.677038                   4.624262
# 31               2.699493            4.246389                   4.862382
# 32               5.403801            2.624406                   3.272080
# 33               2.423561            2.509795                   5.517513
# 34               4.195265            3.551078                   5.295300
# 35               3.703129            3.366171                   3.746159
# 36               5.664400            1.719419                   0.728335
# 37               1.143895            3.184824                   5.622625
# 38               1.641934            4.457556                   2.369067
# 39               1.498214            8.989689                   4.736767
# 40               3.887665            2.042927                   5.066156
# 41               1.530827            8.237424                   4.692616
# 42               4.013178            2.648244                   4.558214
# 43               2.545680            8.883458                   0.471396
# 44               1.611692            8.629570                   1.741419
# 45               3.138034            3.011704                   4.180321
# 46               3.232855            3.613598                   2.867336
# 47               2.116188            8.457354                   1.003704
# 48               2.108269            4.156549                   3.572294
# 49               8.105996            1.585892                   3.172761

# %%
df.describe()
df.to_csv('trials2.csv')
