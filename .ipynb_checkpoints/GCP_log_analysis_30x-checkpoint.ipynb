# %%
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# %%
filenames = [f for f in os.listdir('./run_2_logs') if f[-3:] == 'csv']

# %%
os.getcwd()
# Out:
# '/Users/everyday/UNM/CS_Moses/gcp_data_analysis'

# %%
# df = pd.DataFrame(columns=['trialId', 
#                            'rateOfLayingPheromone', 
#                            'probabilityOfSwitchingToSearching',
#                            'probabilityOfReturningToNest',
#                            'rateOfInformedSearchDecay',
#                            'rateOfSiteFidelity',
#                            'rateOfPheromoneDecay',
#                            'uninformedSearchVariation',
#                            'foodDistribution',
#                            'fitnessScore'
#                           ])
df = pd.DataFrame()

# %%
trialcount = 0;
rowsList = []
for file in filenames:
    with open(os.path.join('./run_2_logs', file)) as csv_file:
        csvreader = csv.DictReader(csv_file)        
        trialcount += 1
        currentTrial = None
        rateOfLayingPheromone = None
        probabilityOfSwitchingToSearching = None
        probabilityOfReturningToNest = None
        rateOfInformedSearchDecay = None
        rateOfSiteFidelity = None
        rateOfPheromoneDecay = None
        uninformedSearchVariation = None
        foodDistribution = []
        fitnessScore = None
        
        for row in csvreader:
#             print(row)
            current_trial = row['labels."ml.googleapis.com/trial_id"']
            message = row['jsonPayload.message'].strip()
            if (currentTrial is None):
                currentTrial = row['labels."ml.googleapis.com/trial_id"']
                print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL {} - {}".format(trialcount, current_trial))
            if ('RateOfLayingPheromone' in message):
                rateOfLayingPheromone = message.split()[1]
#                 print('RateOfLayingPheromone ->', rateOfLayingPheromone)
            if ('ProbabilityOfSwitchingToSearching' in message):
                probabilityOfSwitchingToSearching = message.split()[1]
#                 print('ProbabilityOfSwitchingToSearching ->', probabilityOfSwitchingToSearching)
            if ('ProbabilityOfReturningToNest' in message):
                probabilityOfReturningToNest = message.split()[1]
#                 print('ProbabilityOfReturningToNest ->', probabilityOfReturningToNest)
            if ('RateOfInformedSearchDecay' in message):
                rateOfInformedSearchDecay = message.split()[1]
#                 print('RateOfInformedSearchDecay ->', rateOfInformedSearchDecay)
            if ('RateOfSiteFidelity' in message):
                rateOfSiteFidelity = message.split()[1]
#                 print('RateOfSiteFidelity ->', rateOfSiteFidelity)
            if ('RateOfPheromoneDecay' in message):
                rateOfPheromoneDecay = message.split()[1]
#                 print('RateOfPheromoneDecay ->', rateOfPheromoneDecay)
            if ('UninformedSearchVariation' in message):
                uninformedSearchVariation = message.split()[1]
#                 print('UninformedSearchVariation ->', uninformedSearchVariation)
            if ('food distribution' in message and 'randomizing' not in message):
                pass
#                 print('food distribution ->', message.split()[2])
            if ('food distribution' in message and 'randomizing' not in message):
                foodDistribution.append(message.split()[2])
#                 print('foodDistribution ->', message.split()[2])
            if ('Fitness Score' in message):
                fitnessScore = message.split()[3]
#                 print('Fitness Score ---->', fitnessScore)
#             if (len(foodDistribution) == 30):
# #                 print('FOODS', foodDistribution)
#                 break
        rowsList.append({'currentTrial': int(currentTrial),
                  'rateOfLayingPheromone': float(rateOfLayingPheromone),
                  'probabilityOfSwitchingToSearching': float(probabilityOfSwitchingToSearching),
                  'probabilityOfReturningToNest': float(probabilityOfReturningToNest),
                  'rateOfInformedSearchDecay': float(rateOfInformedSearchDecay),
                  'rateOfSiteFidelity': float(rateOfSiteFidelity),
                  'rateOfPheromoneDecay': float(rateOfPheromoneDecay),
                  'uninformedSearchVariation': float(uninformedSearchVariation),
#                   'foodDistribution': foodDistribution,
                  'fitnessScore': float(fitnessScore)})
            
        print(rowsList)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 1 - 57
# Fitness Score ----> 0.7390625
# RateOfLayingPheromone -> 2.61070747031
# ProbabilityOfSwitchingToSearching -> 0.575400152046
# ProbabilityOfReturningToNest -> 0.000368447885154
# RateOfInformedSearchDecay -> 115.99965881
# RateOfSiteFidelity -> 3.05258101826
# RateOfPheromoneDecay -> 12930.1897402
# UninformedSearchVariation -> 4.0588737819
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 2 - 923
# Fitness Score ----> 0.740885416667
# RateOfLayingPheromone -> 2.11580841982
# ProbabilityOfSwitchingToSearching -> 0.786280891212
# ProbabilityOfReturningToNest -> 2.65891813332e-05
# RateOfInformedSearchDecay -> 1.28053436406
# RateOfSiteFidelity -> 8.51844229208
# RateOfPheromoneDecay -> 4446.97840814
# UninformedSearchVariation -> 1.89620928782
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 3 - 909
# Fitness Score ----> 0.733203125
# RateOfLayingPheromone -> 3.75719700876
# ProbabilityOfSwitchingToSearching -> 0.78468262058
# ProbabilityOfReturningToNest -> 4.79116634692e-05
# RateOfInformedSearchDecay -> 8.23536390387
# RateOfSiteFidelity -> 1.66493333927
# RateOfPheromoneDecay -> 19518.4298064
# UninformedSearchVariation -> 3.78589450174
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 4 - 83
# Fitness Score ----> 0.731380208333
# RateOfLayingPheromone -> 2.39775410161
# ProbabilityOfSwitchingToSearching -> 0.558483890401
# ProbabilityOfReturningToNest -> 0.000284792703128
# RateOfInformedSearchDecay -> 87.6189610325
# RateOfSiteFidelity -> 4.14746816427
# RateOfPheromoneDecay -> 9528.04615006
# UninformedSearchVariation -> 3.11485686143
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 5 - 50
# Fitness Score ----> 0.737239583333
# RateOfLayingPheromone -> 2.91017938802
# ProbabilityOfSwitchingToSearching -> 0.543378157053
# ProbabilityOfReturningToNest -> 0.000412934322304
# RateOfInformedSearchDecay -> 101.758464987
# RateOfSiteFidelity -> 3.39746899096
# RateOfPheromoneDecay -> 6140.80755398
# UninformedSearchVariation -> 3.16869088279
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 6 - 79
# Fitness Score ----> 0.74296875
# RateOfLayingPheromone -> 2.37822419835
# ProbabilityOfSwitchingToSearching -> 0.564560834089
# ProbabilityOfReturningToNest -> 0.000383760600254
# RateOfInformedSearchDecay -> 134.163754514
# RateOfSiteFidelity -> 8.38173096615
# RateOfPheromoneDecay -> 1480.29581263
# UninformedSearchVariation -> 4.03264514461
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 7 - 886
# Fitness Score ----> 0.733203125
# RateOfLayingPheromone -> 2.50185032844
# ProbabilityOfSwitchingToSearching -> 0.300653774836
# ProbabilityOfReturningToNest -> 0.000531391726768
# RateOfInformedSearchDecay -> 8.91357121255
# RateOfSiteFidelity -> 9.46246863535
# RateOfPheromoneDecay -> 3705.03532382
# UninformedSearchVariation -> 5.75662964749
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 8 - 104
# Fitness Score ----> 0.741145833333
# RateOfLayingPheromone -> 4.93040964678
# ProbabilityOfSwitchingToSearching -> 0.539894728477
# ProbabilityOfReturningToNest -> 0.000427399173314
# RateOfInformedSearchDecay -> 144.483967431
# RateOfSiteFidelity -> 3.83112180182
# RateOfPheromoneDecay -> 11686.3021035
# UninformedSearchVariation -> 2.56773305402
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 9 - 851
# Fitness Score ----> 0.759635416667
# RateOfLayingPheromone -> 5.46925063525
# ProbabilityOfSwitchingToSearching -> 0.450839393144
# ProbabilityOfReturningToNest -> 0.00033933663425
# RateOfInformedSearchDecay -> 128.547649249
# RateOfSiteFidelity -> 1.5807899169
# RateOfPheromoneDecay -> 2626.58129632
# UninformedSearchVariation -> 4.52487146566
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 10 - 462
# Fitness Score ----> 0.729296875
# RateOfLayingPheromone -> 4.27019058158
# ProbabilityOfSwitchingToSearching -> 0.357151181652
# ProbabilityOfReturningToNest -> 0.000248236147704
# RateOfInformedSearchDecay -> 114.764416428
# RateOfSiteFidelity -> 0.310286179869
# RateOfPheromoneDecay -> 4836.30276272
# UninformedSearchVariation -> 4.25973194216
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 11 - 476
# Fitness Score ----> 0.734114583333
# RateOfLayingPheromone -> 3.99638785759
# ProbabilityOfSwitchingToSearching -> 0.561767234519
# ProbabilityOfReturningToNest -> 0.000342315899622
# RateOfInformedSearchDecay -> 101.082654627
# RateOfSiteFidelity -> 7.59807213178
# RateOfPheromoneDecay -> 20708.87085
# UninformedSearchVariation -> 3.87740435636
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 12 - 311
# Fitness Score ----> 0.732942708333
# RateOfLayingPheromone -> 5.22185920059
# ProbabilityOfSwitchingToSearching -> 0.414198195927
# ProbabilityOfReturningToNest -> 0.000187607763497
# RateOfInformedSearchDecay -> 31.5847738446
# RateOfSiteFidelity -> 3.09122371164
# RateOfPheromoneDecay -> 1782.888039
# UninformedSearchVariation -> 4.40328056255
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 13 - 148
# Fitness Score ----> 0.757682291667
# RateOfLayingPheromone -> 3.63222731943
# ProbabilityOfSwitchingToSearching -> 0.559105441427
# ProbabilityOfReturningToNest -> 0.000281972594527
# RateOfInformedSearchDecay -> 45.1153214549
# RateOfSiteFidelity -> 9.54565179629
# RateOfPheromoneDecay -> 4130.64025431
# UninformedSearchVariation -> 3.55793162584
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 14 - 558
# Fitness Score ----> 0.732291666667
# RateOfLayingPheromone -> 7.54213619317
# ProbabilityOfSwitchingToSearching -> 0.365769283416
# ProbabilityOfReturningToNest -> 0.000118178883717
# RateOfInformedSearchDecay -> 26.3026977759
# RateOfSiteFidelity -> 2.70006013174
# RateOfPheromoneDecay -> 12086.9286737
# UninformedSearchVariation -> 0.277553545468
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 15 - 175
# Fitness Score ----> 0.738802083333
# RateOfLayingPheromone -> 1.94327295471
# ProbabilityOfSwitchingToSearching -> 0.761342004095
# ProbabilityOfReturningToNest -> 0.000286220852051
# RateOfInformedSearchDecay -> 84.9086712544
# RateOfSiteFidelity -> 6.2154275023
# RateOfPheromoneDecay -> 4571.26940802
# UninformedSearchVariation -> 3.82307644107
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 16 - 161
# Fitness Score ----> 0.739322916667
# RateOfLayingPheromone -> 3.13623736323
# ProbabilityOfSwitchingToSearching -> 0.554372997912
# ProbabilityOfReturningToNest -> 0.000256681131206
# RateOfInformedSearchDecay -> 15.430933864
# RateOfSiteFidelity -> 9.39320786019
# RateOfPheromoneDecay -> 2846.94834592
# UninformedSearchVariation -> 3.55261128382
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 17 - 411
# Fitness Score ----> 0.744010416667
# RateOfLayingPheromone -> 4.48703012596
# ProbabilityOfSwitchingToSearching -> 0.462280642818
# ProbabilityOfReturningToNest -> 0.000409117728499
# RateOfInformedSearchDecay -> 138.236727462
# RateOfSiteFidelity -> 3.76782858094
# RateOfPheromoneDecay -> 16635.0425734
# UninformedSearchVariation -> 4.76935951594
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 18 - 163
# Fitness Score ----> 0.735026041667
# RateOfLayingPheromone -> 4.78043519098
# ProbabilityOfSwitchingToSearching -> 0.435779024352
# ProbabilityOfReturningToNest -> 0.000336706039456
# RateOfInformedSearchDecay -> 0.211933346858
# RateOfSiteFidelity -> 3.81897139443
# RateOfPheromoneDecay -> 4388.78068035
# UninformedSearchVariation -> 3.18243033761
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 19 - 201
# Fitness Score ----> 0.738151041667
# RateOfLayingPheromone -> 2.0009592127
# ProbabilityOfSwitchingToSearching -> 0.32116284783
# ProbabilityOfReturningToNest -> 0.000264881436402
# RateOfInformedSearchDecay -> 0.515256199489
# RateOfSiteFidelity -> 3.97908481508
# RateOfPheromoneDecay -> 2185.21042417
# UninformedSearchVariation -> 4.81962253516
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 20 - 215
# Fitness Score ----> 0.73359375
# RateOfLayingPheromone -> 4.29887054218
# ProbabilityOfSwitchingToSearching -> 0.454639440399
# ProbabilityOfReturningToNest -> 0.000328838484948
# RateOfInformedSearchDecay -> 130.559111701
# RateOfSiteFidelity -> 3.29807329854
# RateOfPheromoneDecay -> 12315.7937416
# UninformedSearchVariation -> 4.22093510832
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 21 - 572
# Fitness Score ----> 0.728515625
# RateOfLayingPheromone -> 1.3789095827
# ProbabilityOfSwitchingToSearching -> 0.71981786244
# ProbabilityOfReturningToNest -> 0.00014296047337
# RateOfInformedSearchDecay -> 90.0899510011
# RateOfSiteFidelity -> 3.86903696719
# RateOfPheromoneDecay -> 1352.54058209
# UninformedSearchVariation -> 3.89241834869
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 22 - 615
# Fitness Score ----> 0.728645833333
# RateOfLayingPheromone -> 1.92593185143
# ProbabilityOfSwitchingToSearching -> 0.54051224127
# ProbabilityOfReturningToNest -> 0.000369741953497
# RateOfInformedSearchDecay -> 140.967718818
# RateOfSiteFidelity -> 4.21449918544
# RateOfPheromoneDecay -> 3182.66138208
# UninformedSearchVariation -> 2.79501140895
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 23 - 814
# Fitness Score ----> 0.7328125
# RateOfLayingPheromone -> 0.840770304732
# ProbabilityOfSwitchingToSearching -> 0.510283292022
# ProbabilityOfReturningToNest -> 0.000323625230438
# RateOfInformedSearchDecay -> 147.258363032
# RateOfSiteFidelity -> 4.55068609869
# RateOfPheromoneDecay -> 1255.2826845
# UninformedSearchVariation -> 6.55415299036
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 24 - 236
# Fitness Score ----> 0.730598958333
# RateOfLayingPheromone -> 2.28507977468
# ProbabilityOfSwitchingToSearching -> 0.789840181438
# ProbabilityOfReturningToNest -> 0.00011112260957
# RateOfInformedSearchDecay -> 2.43736368103
# RateOfSiteFidelity -> 8.74499296212
# RateOfPheromoneDecay -> 19267.3019931
# UninformedSearchVariation -> 5.74011692884
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 25 - 626
# Fitness Score ----> 0.735677083333
# RateOfLayingPheromone -> 2.63325726172
# ProbabilityOfSwitchingToSearching -> 0.50802840687
# ProbabilityOfReturningToNest -> 0.000493376945342
# RateOfInformedSearchDecay -> 93.0652570721
# RateOfSiteFidelity -> 3.97812967722
# RateOfPheromoneDecay -> 9612.47624315
# UninformedSearchVariation -> 3.6421602733
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 26 - 168
# Fitness Score ----> 0.729947916667
# RateOfLayingPheromone -> 0.819967528819
# ProbabilityOfSwitchingToSearching -> 0.75316860533
# ProbabilityOfReturningToNest -> 0.000394640234274
# RateOfInformedSearchDecay -> 64.6424818941
# RateOfSiteFidelity -> 4.60561923782
# RateOfPheromoneDecay -> 12832.6391831
# UninformedSearchVariation -> 6.14279276478
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 27 - 381
# Fitness Score ----> 0.732161458333
# RateOfLayingPheromone -> 3.95129487117
# ProbabilityOfSwitchingToSearching -> 0.722671634836
# ProbabilityOfReturningToNest -> 0.000142409892805
# RateOfInformedSearchDecay -> 14.1358567698
# RateOfSiteFidelity -> 1.52138720623
# RateOfPheromoneDecay -> 21016.5389945
# UninformedSearchVariation -> 5.27989427055
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 28 - 624
# Fitness Score ----> 0.730989583333
# RateOfLayingPheromone -> 3.17861849287
# ProbabilityOfSwitchingToSearching -> 0.38921991985
# ProbabilityOfReturningToNest -> 0.00101877755769
# RateOfInformedSearchDecay -> 2.73574719083
# RateOfSiteFidelity -> 2.49120372449
# RateOfPheromoneDecay -> 10688.558858
# UninformedSearchVariation -> 5.27288037781
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 29 - 750
# Fitness Score ----> 0.734895833333
# RateOfLayingPheromone -> 4.70324727599
# ProbabilityOfSwitchingToSearching -> 0.374009174614
# ProbabilityOfReturningToNest -> 0.000190791634487
# RateOfInformedSearchDecay -> 12.9066985008
# RateOfSiteFidelity -> 2.90612668205
# RateOfPheromoneDecay -> 9264.28287348
# UninformedSearchVariation -> 0.868311453698
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 30 - 341
# Fitness Score ----> 0.772395833333
# RateOfLayingPheromone -> 4.32484369048
# ProbabilityOfSwitchingToSearching -> 0.442560904403
# ProbabilityOfReturningToNest -> 0.000209220216903
# RateOfInformedSearchDecay -> 117.065655403
# RateOfSiteFidelity -> 3.29219480613
# RateOfPheromoneDecay -> 401.990206845
# UninformedSearchVariation -> 3.10351308088
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 31 - 351
# Fitness Score ----> 0.7421875
# RateOfLayingPheromone -> 5.09822124068
# ProbabilityOfSwitchingToSearching -> 0.469438383172
# ProbabilityOfReturningToNest -> 0.000401339959626
# RateOfInformedSearchDecay -> 119.965550594
# RateOfSiteFidelity -> 2.67703776175
# RateOfPheromoneDecay -> 20411.788235
# UninformedSearchVariation -> 4.62426216605
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 32 - 225
# Fitness Score ----> 0.731640625
# RateOfLayingPheromone -> 2.69949341783
# ProbabilityOfSwitchingToSearching -> 0.319697027768
# ProbabilityOfReturningToNest -> 0.000367263673853
# RateOfInformedSearchDecay -> 45.984988026
# RateOfSiteFidelity -> 4.24638929783
# RateOfPheromoneDecay -> 12927.1086143
# UninformedSearchVariation -> 4.86238179636
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 33 - 352
# Fitness Score ----> 0.744921875
# RateOfLayingPheromone -> 5.40380081495
# ProbabilityOfSwitchingToSearching -> 0.471494409869
# ProbabilityOfReturningToNest -> 0.000295431535835
# RateOfInformedSearchDecay -> 130.379507514
# RateOfSiteFidelity -> 2.62440552475
# RateOfPheromoneDecay -> 20726.5363844
# UninformedSearchVariation -> 3.27207981812
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 34 - 569
# Fitness Score ----> 0.732421875
# RateOfLayingPheromone -> 2.4235614055
# ProbabilityOfSwitchingToSearching -> 0.794662753491
# ProbabilityOfReturningToNest -> 3.99253678099e-05
# RateOfInformedSearchDecay -> 126.133041094
# RateOfSiteFidelity -> 2.5097954043
# RateOfPheromoneDecay -> 7292.84890534
# UninformedSearchVariation -> 5.51751302924
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 35 - 964
# Fitness Score ----> 0.728255208333
# RateOfLayingPheromone -> 4.19526468742
# ProbabilityOfSwitchingToSearching -> 0.424619509789
# ProbabilityOfReturningToNest -> 0.000152318993998
# RateOfInformedSearchDecay -> 30.4358898805
# RateOfSiteFidelity -> 3.55107781426
# RateOfPheromoneDecay -> 20673.3381372
# UninformedSearchVariation -> 5.29529976249
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 36 - 145
# Fitness Score ----> 0.737239583333
# RateOfLayingPheromone -> 3.70312865621
# ProbabilityOfSwitchingToSearching -> 0.759936949889
# ProbabilityOfReturningToNest -> 9.06736985724e-05
# RateOfInformedSearchDecay -> 134.702759009
# RateOfSiteFidelity -> 3.3661713344
# RateOfPheromoneDecay -> 3295.59244816
# UninformedSearchVariation -> 3.74615925263
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 37 - 804
# Fitness Score ----> 0.7328125
# RateOfLayingPheromone -> 5.66440024843
# ProbabilityOfSwitchingToSearching -> 0.396366183536
# ProbabilityOfReturningToNest -> 0.000162906569272
# RateOfInformedSearchDecay -> 35.6859914773
# RateOfSiteFidelity -> 1.71941862777
# RateOfPheromoneDecay -> 11402.6159074
# UninformedSearchVariation -> 0.728334838545
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 38 - 421
# Fitness Score ----> 0.733463541667
# RateOfLayingPheromone -> 1.14389458825
# ProbabilityOfSwitchingToSearching -> 0.378133146645
# ProbabilityOfReturningToNest -> 0.000214865172813
# RateOfInformedSearchDecay -> 1.20533927743
# RateOfSiteFidelity -> 3.18482360876
# RateOfPheromoneDecay -> 1389.90775709
# UninformedSearchVariation -> 5.62262505925
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 39 - 718
# Fitness Score ----> 0.740234375
# RateOfLayingPheromone -> 1.64193441042
# ProbabilityOfSwitchingToSearching -> 0.405247554278
# ProbabilityOfReturningToNest -> 0.000175254702947
# RateOfInformedSearchDecay -> 7.91739071313
# RateOfSiteFidelity -> 4.45755566357
# RateOfPheromoneDecay -> 18648.0435091
# UninformedSearchVariation -> 2.36906671381
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 40 - 255
# Fitness Score ----> 0.73203125
# RateOfLayingPheromone -> 1.49821428496
# ProbabilityOfSwitchingToSearching -> 0.776770257982
# ProbabilityOfReturningToNest -> 2.52797850541e-05
# RateOfInformedSearchDecay -> 3.02391829211
# RateOfSiteFidelity -> 8.9896890557
# RateOfPheromoneDecay -> 680.992900566
# UninformedSearchVariation -> 4.73676654569
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 41 - 530
# Fitness Score ----> 0.738802083333
# RateOfLayingPheromone -> 3.88766464075
# ProbabilityOfSwitchingToSearching -> 0.741876785528
# ProbabilityOfReturningToNest -> 4.81273433331e-05
# RateOfInformedSearchDecay -> 72.0620596684
# RateOfSiteFidelity -> 2.04292705549
# RateOfPheromoneDecay -> 5888.87561846
# UninformedSearchVariation -> 5.06615592972
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 42 - 440
# Fitness Score ----> 0.731901041667
# RateOfLayingPheromone -> 1.53082663777
# ProbabilityOfSwitchingToSearching -> 0.484287768805
# ProbabilityOfReturningToNest -> 0.00039704130442
# RateOfInformedSearchDecay -> 28.2616372593
# RateOfSiteFidelity -> 8.23742428535
# RateOfPheromoneDecay -> 13782.8834565
# UninformedSearchVariation -> 4.69261584585
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 43 - 65
# Fitness Score ----> 0.732942708333
# RateOfLayingPheromone -> 4.01317755275
# ProbabilityOfSwitchingToSearching -> 0.563297376025
# ProbabilityOfReturningToNest -> 0.000273413499696
# RateOfInformedSearchDecay -> 125.921704529
# RateOfSiteFidelity -> 2.64824393327
# RateOfPheromoneDecay -> 16405.9167886
# UninformedSearchVariation -> 4.55821409261
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 44 - 722
# Fitness Score ----> 0.73984375
# RateOfLayingPheromone -> 2.54568044138
# ProbabilityOfSwitchingToSearching -> 0.305342767947
# ProbabilityOfReturningToNest -> 0.000576843840133
# RateOfInformedSearchDecay -> 89.551576383
# RateOfSiteFidelity -> 8.88345833917
# RateOfPheromoneDecay -> 2898.78690565
# UninformedSearchVariation -> 0.471396214595
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 45 - 680
# Fitness Score ----> 0.775911458333
# RateOfLayingPheromone -> 1.61169170986
# ProbabilityOfSwitchingToSearching -> 0.774707966399
# ProbabilityOfReturningToNest -> 6.39819290049e-05
# RateOfInformedSearchDecay -> 0.917383407269
# RateOfSiteFidelity -> 8.62956967241
# RateOfPheromoneDecay -> 7713.04375408
# UninformedSearchVariation -> 1.74141877504
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 46 - 441
# Fitness Score ----> 0.729036458333
# RateOfLayingPheromone -> 3.13803387376
# ProbabilityOfSwitchingToSearching -> 0.575908065884
# ProbabilityOfReturningToNest -> 1.65176079725e-05
# RateOfInformedSearchDecay -> 40.8145039911
# RateOfSiteFidelity -> 3.01170440644
# RateOfPheromoneDecay -> 16388.7718995
# UninformedSearchVariation -> 4.18032113185
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 47 - 333
# Fitness Score ----> 0.736067708333
# RateOfLayingPheromone -> 3.23285537592
# ProbabilityOfSwitchingToSearching -> 0.597507997581
# ProbabilityOfReturningToNest -> 0.000324944881024
# RateOfInformedSearchDecay -> 129.761781833
# RateOfSiteFidelity -> 3.61359752158
# RateOfPheromoneDecay -> 10501.5217028
# UninformedSearchVariation -> 2.86733564739
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 48 - 696
# Fitness Score ----> 0.740885416667
# RateOfLayingPheromone -> 2.1161879796
# ProbabilityOfSwitchingToSearching -> 0.786496146506
# ProbabilityOfReturningToNest -> 0.000158022420872
# RateOfInformedSearchDecay -> 145.964818045
# RateOfSiteFidelity -> 8.45735372695
# RateOfPheromoneDecay -> 293.021754296
# UninformedSearchVariation -> 1.00370372825
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 49 - 127
# Fitness Score ----> 0.741276041667
# RateOfLayingPheromone -> 2.10826872939
# ProbabilityOfSwitchingToSearching -> 0.764205806985
# ProbabilityOfReturningToNest -> 4.08738942048e-05
# RateOfInformedSearchDecay -> 0.740577235126
# RateOfSiteFidelity -> 4.15654936894
# RateOfPheromoneDecay -> 1315.69962617
# UninformedSearchVariation -> 3.57229441116
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TRIAL 50 - 523
# Fitness Score ----> 0.744921875
# RateOfLayingPheromone -> 8.10599644503
# ProbabilityOfSwitchingToSearching -> 0.580067597015
# ProbabilityOfReturningToNest -> 1.61998155425e-05
# RateOfInformedSearchDecay -> 137.334987055
# RateOfSiteFidelity -> 1.58589212688
# RateOfPheromoneDecay -> 3822.40024814
# UninformedSearchVariation -> 3.17276068172

# %%
df = pd.DataFrame(rowsList)
df
# Out:
#     currentTrial  fitnessScore  probabilityOfReturningToNest  \
# 0            339      0.737500                  1.555742e-04
# 1            514      0.755469                  1.437065e-04
# 2             15      0.733594                  3.546404e-10
# 3            703      0.729297                  5.709977e-07
# 4            878      0.750000                  1.967034e-05
# 5            471      0.734375                  3.105574e-06
# 6            263      0.740625                  1.502858e-05
# 7            100      0.732422                  9.110798e-04
# 8            300      0.743359                  1.060691e-08
# 9            261      0.743750                  1.203471e-04
# 10           575      0.770312                  2.404508e-04
# 11           365      0.727734                  1.118405e-06
# 12           211      0.727344                  1.537781e-03
# 13           563      0.730859                  2.728465e-04
# 14            76      0.728516                  1.545244e-03
# 15           374      0.732812                  5.175354e-04
# 16           599      0.730078                  4.447938e-07
# 17           770      0.728125                  4.604664e-11
# 18           613      0.728906                  1.543175e-03
# 19           217      0.728906                  1.787802e-03
# 20           571      0.752344                  9.486881e-09
# 21           767      0.727734                  7.707316e-04
# 22           799      0.751172                  8.720535e-04
# 23           606      0.742578                  1.238868e-05
# 24           385      0.737891                  2.062940e-03
# 25           580      0.732031                  3.090959e-06
# 26           231      0.765625                  1.036898e-03
# 27           190      0.745703                  5.846121e-07
# 28           341      0.735156                  8.827052e-05
# 29           792      0.728125                  1.499026e-03
# 30           591      0.739844                  1.087367e-05
# 31           432      0.731250                  2.701974e-06
# 32           340      0.758984                  1.982275e-04
# 33           142      0.749609                  1.329395e-03
# 34           829      0.764062                  3.466970e-04
# 35           356      0.734766                  7.768859e-04
# 36           544      0.728906                  1.283352e-05
# 37           237      0.739844                  9.253825e-04
# 38           872      0.726953                  2.132336e-07
# 39           133      0.739453                  1.381863e-03
# 40           469      0.736328                  8.636045e-12
# 41           482      0.728906                  8.960780e-08
# 42           722      0.741797                  1.847620e-04
# 43           246      0.729688                  9.972200e-04
# 44           656      0.732422                  1.872031e-03
# 45           727      0.740625                  1.393695e-03
# 46           531      0.758984                  2.106526e-09
# 47           296      0.755859                  1.338671e-07
# 48           917      0.733203                  2.194812e-09
# 49           888      0.746484                  7.896378e-04
#
#     probabilityOfSwitchingToSearching  rateOfInformedSearchDecay  \
# 0                            0.269269                 148.276802
# 1                            0.832274                  19.597635
# 2                            0.407124                  56.225405
# 3                            0.273039                  89.184594
# 4                            0.438045                  73.211801
# 5                            0.999778                  83.963723
# 6                            0.659331                 148.403668
# 7                            0.159592                 118.596117
# 8                            0.743839                  33.676473
# 9                            0.520250                 122.355104
# 10                           0.313219                 146.494911
# 11                           0.616459                 134.225085
# 12                           0.791526                 138.964280
# 13                           0.795377                   0.247171
# 14                           0.597547                 142.133281
# 15                           0.345538                 109.936564
# 16                           0.315381                  18.817560
# 17                           0.425705                  83.644152
# 18                           0.761423                 111.746027
# 19                           0.744342                 127.352763
# 20                           0.635920                  35.563300
# 21                           0.872115                  78.193056
# 22                           0.342285                 125.318882
# 23                           0.869675                  26.381593
# 24                           0.797436                  65.277849
# 25                           0.999653                 107.329460
# 26                           0.576277                 136.635012
# 27                           0.649921                  89.759459
# 28                           0.523498                 107.580473
# 29                           0.334987                  89.355041
# 30                           0.662802                   1.035484
# 31                           0.693303                 148.404465
# 32                           0.363574                 141.752654
# 33                           0.934996                 109.838465
# 34                           0.549494                 142.428936
# 35                           0.100867                   0.970618
# 36                           0.586494                  99.419470
# 37                           0.372748                  81.884593
# 38                           0.760009                   5.135982
# 39                           0.281778                  47.586334
# 40                           0.549462                  90.899360
# 41                           0.871189                   0.592237
# 42                           0.976869                 114.811319
# 43                           0.440990                 126.704412
# 44                           0.946644                 124.308678
# 45                           0.245964                 116.852709
# 46                           0.603444                 129.658871
# 47                           0.744718                  33.512161
# 48                           0.247318                  39.854651
# 49                           0.521276                   5.236391
#
#     rateOfLayingPheromone  rateOfPheromoneDecay  rateOfSiteFidelity  \
# 0                4.455849          17939.071996        4.224562e+00
# 1                4.688254          21261.163242        1.917881e+00
# 2                7.912707           4224.453331        1.026320e+00
# 3                0.000005          13592.504587        1.218393e+01
# 4                2.346154          10789.079969        4.066580e+00
# 5                0.001706           3716.055549        1.510379e+01
# 6               14.973822          12912.769717        3.391145e-03
# 7                3.110817          16905.956235        1.350606e+01
# 8                6.457590          17998.679271        1.068846e+00
# 9               14.582670           9690.813475        9.679057e-01
# 10               1.528149          17150.444094        5.536781e+00
# 11              17.643305          11466.981947        1.993386e-05
# 12               4.284065          13810.046890        2.770186e+00
# 13               1.646835          19492.098020        5.281586e+00
# 14               8.910421          15519.756297        3.544446e+00
# 15               1.083116          12766.149725        1.170181e+01
# 16               9.035101          10972.369570        3.986499e-06
# 17              14.917947           9378.711376        1.173451e-07
# 18               0.634025          11658.395763        1.570639e+01
# 19              15.558802          19644.613720        1.900559e+00
# 20               0.001705          18080.273334        1.750913e+01
# 21               1.208566          17577.202946        1.992886e+01
# 22              13.689730          15840.959663        7.123194e-01
# 23               0.009148           9786.067691        1.918618e+01
# 24               0.720099          20576.985293        1.119061e+01
# 25               0.000275          18389.530748        1.838811e+01
# 26               3.133989           6490.820926        4.956033e+00
# 27              19.999448           6880.903900        4.408654e-05
# 28               1.629163           5440.168686        1.794550e+01
# 29               2.099298          12160.696567        2.557945e+00
# 30               5.521520          17540.683792        2.380918e+00
# 31               2.347056          11923.518433        1.773545e+01
# 32               2.621755           4908.578388        6.222901e-01
# 33               0.806637          16731.680992        7.650313e+00
# 34               5.421069             77.263188        1.800093e+00
# 35               1.758314           6224.396567        1.253995e+01
# 36              16.047621          14350.957917        8.993007e-03
# 37               2.639461           3885.329824        1.000013e+01
# 38              17.859468             70.121024        7.807530e-04
# 39               2.686276          15500.012949        1.107174e-01
# 40              15.452487          10767.842708        8.644774e-07
# 41              13.119363          22009.701628        1.397071e-04
# 42              13.446812          20624.119464        2.889177e+00
# 43              16.919976           4910.013903        1.927756e-01
# 44               3.070204          19702.491212        9.829981e-01
# 45              19.544672          14050.633511        3.348750e-02
# 46               1.690591            946.944012        9.512314e+00
# 47               6.435259          17990.538497        1.036348e+00
# 48               7.669346           9103.823277        1.903742e-03
# 49               2.595757            183.430182        1.426286e+01
#
#     uninformedSearchVariation
# 0                    3.467002
# 1                    0.286056
# 2                    3.660786
# 3                    2.134279
# 4                    0.471648
# 5                    5.286948
# 6                    1.694653
# 7                    5.206208
# 8                    7.834853
# 9                    0.382228
# 10                   0.830610
# 11                   5.572458
# 12                   4.398084
# 13                   2.711943
# 14                   1.753130
# 15                   1.380775
# 16                   6.302285
# 17                   4.011106
# 18                   0.269885
# 19                   2.185936
# 20                   0.228730
# 21                   4.728762
# 22                   1.002076
# 23                   0.457390
# 24                   0.031097
# 25                   4.514878
# 26                   3.109015
# 27                   5.465920
# 28                   1.863131
# 29                   5.926319
# 30                   5.555366
# 31                   0.003533
# 32                   0.083672
# 33                   2.557412
# 34                   2.511775
# 35                   4.082326
# 36                   5.915519
# 37                   0.934496
# 38                   5.739260
# 39                   2.044343
# 40                   4.961637
# 41                  10.631558
# 42                   6.314995
# 43                   2.739277
# 44                   1.195279
# 45                   4.954064
# 46                   1.024105
# 47                   7.848782
# 48                   4.998448
# 49                   0.015698

# %%
df.describe()
df.to_csv('trials.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-88f93ae4742a> in <module>()
#       1 # Select features to include in the plot
#       2 plot_feat = ['probabilityOfReturningToNest', 'probabilityOfSwitchingToSearching', 'rateOfInformedSearchDecay', 'rateOfLayingPheromone','fitnessScore']
# ----> 3 X_norm = (X - X.min())/(X.max() - X.min())
#       4
#       5 # Concat classes with the normalized data
#
# NameError: name 'X' is not defined
